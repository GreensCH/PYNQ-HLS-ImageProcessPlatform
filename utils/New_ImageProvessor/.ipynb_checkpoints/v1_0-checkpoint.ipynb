# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from pynq import allocate, Overlay,GPIO
from pynq import lib
from pynq.lib.video import *

import cv2 as cv2

# %%
design = Overlay("v1_0.bit")
design?
my_dma = design.axi_vdma_0
my_img_ip = design.ImageProcessHandler_0

# %%
image_path = "../pictures/lena.jpg"
mat_image = cv.imread(image_path,cv.IMREAD_UNCHANGED)
#测试用Ipl格式原图
original_plt_image = Image.open(image_path)
#Mat转PLT
plt_image = Image.fromarray(cv.cvtColor(mat_image,cv.COLOR_BGR2RGB))
#通道变化
rgba_plt_image=plt_image.convert('RGBA')
plt.imshow(rgba_plt_image)
#获取高度宽度
width, height = plt_image.size

# %%
#写入内存映射宽高
my_img_ip.write(0x10, 1)
my_img_ip.write(0x18, height)
my_img_ip.write(0x20, width)
my_img_ip.write(0x00,0x81) # start 必须加不然卡死

my_dma.readchannel.mode=VideoMode(width,height,32)
my_dma.readchannel.start()

my_dma.writechannel.mode=VideoMode(width,height,32)
my_dma.writechannel.start()

img_frame = my_dma.writechannel.newframe()

#申请内存存入输入图像
out_frame = allocate(shape=(height, width, 4), 
                            dtype=np.uint8, cacheable=1)

img_frame[:]=np.array(rgba_plt_image)#original_plt_image#np.array(original_image)
my_dma.writechannel.writeframe(img_frame)

# %%
while True:
    if(my_dma.readchannel.activeframe == 0):
        out_frame = my_dma.readchannel.readframe()
        plt_image_out = Image.fromarray(out_frame)
        display(plt_image_out)
        break;
my_dma.readchannel.stop()
my_dma.writechannel.stop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-92f0c460427a> in <module>()
#       1 while True:
# ----> 2     if(my_dma.readchannel.activeframe == 0):
#       3         out_frame = my_dma.readchannel.readframe()
#       4         plt_image_out = Image.fromarray(out_frame)
#       5         display(plt_image_out)
#
# /usr/local/lib/python3.6/dist-packages/pynq/lib/video/dma.py in activeframe(self)
#     224             """
#     225             self._mmio.write(0x34, 0x4090)
# --> 226             return (self._mmio.read(0x28) >> 24) & 0x1F
#     227
#     228         @property
#
# /usr/local/lib/python3.6/dist-packages/pynq/mmio.py in read(self, offset, length, word_order)
#     153                 return (lsb << 32) + int(self.array[idx+1])
#     154         else:
# --> 155             return lsb & ((2**(8*length)) - 1)
#     156
#     157     def write_mm(self, offset, data):
#
# KeyboardInterrupt:

# %%
my_dma.readchannel.stop()
my_dma.writechannel.stop()

# %%
del out_frame
del img_frame
del height
del width
